# %% [markdown]
# <h1>Box plot </h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.rand(100)
print(data)
# Out:
# [0.68078423 0.74069348 0.44213784 0.80108099 0.27206969 0.38529451
#  0.22408925 0.52584798 0.93477337 0.18073233 0.71180496 0.62819064
#  0.82728102 0.52307508 0.36505112 0.41696521 0.66556755 0.9838459
#  0.3721958  0.99779441 0.16919461 0.75417166 0.62686924 0.1946345
#  0.36214279 0.37479527 0.57662909 0.80930918 0.47559756 0.28995515
#  0.90418809 0.04688251 0.42556102 0.07724422 0.66346189 0.69528102
#  0.63064317 0.82872919 0.37380918 0.55392389 0.7093251  0.95605596
#  0.29726841 0.87689325 0.72913557 0.74163531 0.75922285 0.98417798
#  0.86184213 0.75476794 0.15179564 0.48317355 0.57223865 0.05257091
#  0.68951604 0.18912115 0.79404385 0.96785103 0.69906002 0.60060199
#  0.04374774 0.68057323 0.41365719 0.87367385 0.99071049 0.87794602
#  0.28190435 0.8339359  0.77069116 0.5466797  0.37846929 0.5510565
#  0.41978036 0.06255645 0.25673973 0.12003066 0.01952856 0.9146382
#  0.91487738 0.04618642 0.26481285 0.37550266 0.33813808 0.11073462
#  0.2325024  0.40215439 0.1363894  0.90382478 0.35598278 0.01193072
#  0.70799841 0.8622718  0.3862449  0.4161364  0.7542329  0.40261071
#  0.29863311 0.3003913  0.76459845 0.67588218]

# %%
plt.boxplot(data, notch=True)
plt.show()
df = pd.DataFrame(data)
df.describe()
# Out:
#                 0
# count  100.000000
# mean     0.530810
# std      0.281871
# min      0.011931
# 25%      0.299952
# 50%      0.548868
# 75%      0.755882
# max      0.997794

# %%
datasets = pd.read_csv('/workspaces/python2/Datasets/auto-mpg.csv')
plt.boxplot(datasets['mpg'], widths=0.75, notch=True)
plt.show()

# %%
x1 = 5*np.random.rand(50)
x2 = 5*np.random.rand(50)
x3 = 30*np.random.rand(25)
x = np.concatenate((x1, x2, x3))
y1 = 5*np.random.rand(50)
y2 = 5*np.random.rand(50) + 25
y3 = 30*np.random.rand(25)

y = np.concatenate((y1, y2, y3))

plt.scatter(x, y, marker='>', s=[50], c='m')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
time = range(1, 13)
income = np.array([5, 9, 6, 6, 10, 7, 6, 4, 4, 5, 6, 4])
expenses = np.array([6, 6, 8, 3, 6, 9, 7, 8, 6, 6, 4, 8])
# Initialize figure and axis
fig, ax = plt.subplots(figsize=(8, 8))
# Plot lines
ax.plot(time, income, color="green")
ax.plot(time, expenses, color="red")
# Fill area when income > expenses with green
ax.fill_between(
    time, income, expenses, where=(income > expenses),
    color="green", alpha=0.25,
    label="Positive", interpolate=False
)
# Fill area when income <= expenses with red
ax.fill_between(
    time, income, expenses, where=(income <= expenses),
    color="red", alpha=0.25,
    label="Negative", interpolate=False)
print(time)
plt.xlabel('time')
plt.xticks(range(1, 13))
plt.ylabel('income/expense comparison')
ax.legend()
plt.show()
# Out:
# range(1, 13)

# %%
import seaborn as sns

ax = sns.regplot(x='mpg',y='acceleration',data=datasets,marker='+',scatter_kws={'color':'black','s':200},color='g')
ax.set(xlabel='mpg',ylabel='acceleration')
ax.set_title('mpg vs acceleration')
plt.show()

# %%
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))

hm = sns.heatmap(data=data,annot=True)
plt.show()

# %%
# !pip install pywaffle
# Out:
# Collecting pywaffle
#   Downloading pywaffle-1.1.0-py2.py3-none-any.whl (30 kB)
# Collecting fontawesomefree (from pywaffle)
#   Downloading fontawesomefree-6.4.0-py3-none-any.whl (25.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.2/25.2 MB 33.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from pywaffle) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->pywaffle) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# Installing collected packages: fontawesomefree, pywaffle
# Successfully installed fontawesomefree-6.4.0 pywaffle-1.1.0
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
python -m pip install
